# %%
import pandas as pd

pd.set_option('display.max_rows', 10)

# Create an empty DataFrame with the specified columns
df = pd.read_csv("data50.csv", index_col=0)
df2 = pd.read_csv("data20.csv", index_col=0)

# Show the empty DataFrame
data = df

# %%
# Replace NaN values with 0
data_filled = data.fillna(0)

# Ensure all columns except 'replicates' (since it might contain non-numeric values originally) are numeric
data_filled = data_filled.apply(pd.to_numeric, errors='ignore')

# Display the data types to confirm changes
data_filled.dtypes, data_filled.head()

data_filled
# Out:
#       round replicates  duplicates  distortion        m1        m2        m3  \
# 0        -1        _21       100.0           1  1.000000  0.794769  0.885650
# 1        -1        _21         8.0           1  1.000000  0.688249  0.815341
# 2        -1        _21         1.0           0  0.997807  0.919192  0.956888
# 3        -1        _21         0.1           0  0.967742  0.952381  0.960000
# 4        -1        _21       100.0           0  1.000000  0.921762  0.959288
# ...     ...        ...         ...         ...       ...       ...       ...
# 2911    -12        _50       100.0           1  0.997545  0.817572  0.898636
# 2912    -12        _50         0.1           1  1.000000  0.783333  0.878505
# 2913    -12        _50         1.0           1  0.987113  0.786448  0.875429
# 2914    -12        _50         0.1           0  0.967742  0.952381  0.960000
# 2915    -12        _50         1.0           0  1.000000  0.919192  0.957895
#
#                           date
# 0     Fri_Feb__9_08_51_26_2024
# 1     Fri_Feb__9_08_51_30_2024
# 2     Tue_Feb__6_20_11_45_2024
# 3     Tue_Feb__6_20_11_41_2024
# 4     Tue_Feb__6_20_11_52_2024
# ...                        ...
# 2911  Thu_Feb_29_00_22_02_2024
# 2912  Thu_Feb_29_00_21_57_2024
# 2913  Thu_Feb_29_15_18_15_2024
# 2914  Thu_Feb_29_00_21_41_2024
# 2915  Thu_Feb_29_00_21_45_2024
#
# [2916 rows x 8 columns]

# %%
# Remove "_" from the 'replicates' column and convert to numeric if possible
data_filled['replicates'] = data_filled['replicates'].astype(str).str.replace("_", "")
data_filled['replicates'] = pd.to_numeric(data_filled['replicates'], errors='coerce').fillna(0)

# Make 'round' and 'split' values positive
data_filled['round'] = data_filled['round'].abs()


# Rename columns 'm1', 'm2', 'm3' to 'precision', 'recall', 'f1score'
data_renamed = data_filled.rename(columns={'m1': 'precision', 'm2': 'recall', 'm3': 'f1score'})

# Display the first few rows to confirm the column names have been updated
data_renamed
# Out:
#       round  replicates  duplicates  distortion  precision    recall  \
# 0         1          21       100.0           1   1.000000  0.794769
# 1         1          21         8.0           1   1.000000  0.688249
# 2         1          21         1.0           0   0.997807  0.919192
# 3         1          21         0.1           0   0.967742  0.952381
# 4         1          21       100.0           0   1.000000  0.921762
# ...     ...         ...         ...         ...        ...       ...
# 2911     12          50       100.0           1   0.997545  0.817572
# 2912     12          50         0.1           1   1.000000  0.783333
# 2913     12          50         1.0           1   0.987113  0.786448
# 2914     12          50         0.1           0   0.967742  0.952381
# 2915     12          50         1.0           0   1.000000  0.919192
#
#        f1score                      date
# 0     0.885650  Fri_Feb__9_08_51_26_2024
# 1     0.815341  Fri_Feb__9_08_51_30_2024
# 2     0.956888  Tue_Feb__6_20_11_45_2024
# 3     0.960000  Tue_Feb__6_20_11_41_2024
# 4     0.959288  Tue_Feb__6_20_11_52_2024
# ...        ...                       ...
# 2911  0.898636  Thu_Feb_29_00_22_02_2024
# 2912  0.878505  Thu_Feb_29_00_21_57_2024
# 2913  0.875429  Thu_Feb_29_15_18_15_2024
# 2914  0.960000  Thu_Feb_29_00_21_41_2024
# 2915  0.957895  Thu_Feb_29_00_21_45_2024
#
# [2916 rows x 8 columns]

# %%
# Define a function to map 'round' values to model names
def map_round_to_model(round_number):
    if 1 <= round_number <= 3:
        return "Both"
    elif 4 <= round_number <= 6:
        return "No Diri"
    elif 7 <= round_number <= 9:
        return "None"
    elif 10 <= round_number <= 12:
        return "No Empirical"
    else:
        return "Unknown"  # For any round numbers outside the specified ranges

# Apply the mapping function to the 'round' column to create the new 'model' column
data_renamed['model'] = data_renamed['round'].apply(map_round_to_model)



# Define a function to map 'round' values to prior categories
def map_round_to_prior(round_number):
    if round_number in [1, 4, 7, 10]:
        return "Pitman"
    elif round_number in [2, 5, 8, 11]:
        return "uniform"
    elif round_number in [3, 6, 9, 12]:
        return "Bounded NBD"
    else:
        return "Unknown"  # For any round numbers outside the specified or considered ranges

# Apply the mapping function to the 'round' column to create the new 'prior' column
data_renamed['prior'] = data_renamed['round'].apply(map_round_to_prior)

# Define a function to map 'duplicates' values to duplicates level categories
def map_duplicates_to_level(duplicates_value):
    if duplicates_value == 0.1:
        return "Low"
    elif duplicates_value == 1.0:
        return "Medium"
    elif duplicates_value == 8.0:
        return "High"
    elif duplicates_value == 100.0:
        return "Very High"
    else:
        return "Unknown"  # For any duplicates values outside the specified ranges

# Apply the mapping function to the 'duplicates' column to create the new 'duplicates_level' column
data_renamed['duplicates_level'] = data_renamed['duplicates'].apply(map_duplicates_to_level)

# Define a function to map 'distortion' values to distortion level categories
def map_distortion_to_level(distortion_value):
    if distortion_value == 0:
        return "Low"
    elif distortion_value == 1:
        return "High"
    else:
        return "Unknown"  # For any distortion values outside the specified values

# Apply the mapping function to the 'distortion' column to create the new 'distortion_level' column
data_renamed['distortion_level'] = data_renamed['distortion'].apply(map_distortion_to_level)

def map_iter_to_num(iter):
    if iter == '10k':
        return 10000
    elif iter == '50k':
        return 50000
    else:
        return 0  # For any distortion values outside the specified values


# Select only the specified columns
data_selected_columns = data_renamed[['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates', "date"]]

# Select and reorder the dataset with only the specified columns
data_final = data_renamed[['model', 'prior', 'duplicates_level', 'distortion_level',
                           'replicates', 'precision', 'recall', 'f1score', "date"]]

# Display the first few rows to confirm the changes
data_final
# Out:
#              model        prior duplicates_level distortion_level  replicates  \
# 0             Both       Pitman        Very High             High          21
# 1             Both       Pitman             High             High          21
# 2             Both       Pitman           Medium              Low          21
# 3             Both       Pitman              Low              Low          21
# 4             Both       Pitman        Very High              Low          21
# ...            ...          ...              ...              ...         ...
# 2911  No Empirical  Bounded NBD        Very High             High          50
# 2912  No Empirical  Bounded NBD              Low             High          50
# 2913  No Empirical  Bounded NBD           Medium             High          50
# 2914  No Empirical  Bounded NBD              Low              Low          50
# 2915  No Empirical  Bounded NBD           Medium              Low          50
#
#       precision    recall   f1score                      date
# 0      1.000000  0.794769  0.885650  Fri_Feb__9_08_51_26_2024
# 1      1.000000  0.688249  0.815341  Fri_Feb__9_08_51_30_2024
# 2      0.997807  0.919192  0.956888  Tue_Feb__6_20_11_45_2024
# 3      0.967742  0.952381  0.960000  Tue_Feb__6_20_11_41_2024
# 4      1.000000  0.921762  0.959288  Tue_Feb__6_20_11_52_2024
# ...         ...       ...       ...                       ...
# 2911   0.997545  0.817572  0.898636  Thu_Feb_29_00_22_02_2024
# 2912   1.000000  0.783333  0.878505  Thu_Feb_29_00_21_57_2024
# 2913   0.987113  0.786448  0.875429  Thu_Feb_29_15_18_15_2024
# 2914   0.967742  0.952381  0.960000  Thu_Feb_29_00_21_41_2024
# 2915   1.000000  0.919192  0.957895  Thu_Feb_29_00_21_45_2024
#
# [2916 rows x 9 columns]

# %%
data_cleaned = data_final

# Finding duplicates and keeping them to show
duplicates_to_show = data_cleaned[data_cleaned.duplicated(subset=['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates'], keep='first')]
duplicates_to_show2 = data_cleaned[data_cleaned.duplicated(subset=['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates'], keep='last')]

duplicates_to_show3 = pd.concat([duplicates_to_show, duplicates_to_show2])

# Sorting the duplicates for better readability
duplicates_to_show3 = duplicates_to_show3.sort_values(by=['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates'])

pd.set_option('display.max_rows', 10)

duplicates_to_show3 = duplicates_to_show3[(duplicates_to_show3['precision'] >= 0.3) & (duplicates_to_show3['recall'] >= 0.3)]

data_cleaned.drop_duplicates(subset=['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates'], keep=False)

# duplicates_to_show3
# Out:
#              model        prior duplicates_level distortion_level  replicates  \
# 0             Both       Pitman        Very High             High          21
# 1             Both       Pitman             High             High          21
# 2             Both       Pitman           Medium              Low          21
# 3             Both       Pitman              Low              Low          21
# 4             Both       Pitman        Very High              Low          21
# ...            ...          ...              ...              ...         ...
# 2911  No Empirical  Bounded NBD        Very High             High          50
# 2912  No Empirical  Bounded NBD              Low             High          50
# 2913  No Empirical  Bounded NBD           Medium             High          50
# 2914  No Empirical  Bounded NBD              Low              Low          50
# 2915  No Empirical  Bounded NBD           Medium              Low          50
#
#       precision    recall   f1score                      date
# 0      1.000000  0.794769  0.885650  Fri_Feb__9_08_51_26_2024
# 1      1.000000  0.688249  0.815341  Fri_Feb__9_08_51_30_2024
# 2      0.997807  0.919192  0.956888  Tue_Feb__6_20_11_45_2024
# 3      0.967742  0.952381  0.960000  Tue_Feb__6_20_11_41_2024
# 4      1.000000  0.921762  0.959288  Tue_Feb__6_20_11_52_2024
# ...         ...       ...       ...                       ...
# 2911   0.997545  0.817572  0.898636  Thu_Feb_29_00_22_02_2024
# 2912   1.000000  0.783333  0.878505  Thu_Feb_29_00_21_57_2024
# 2913   0.987113  0.786448  0.875429  Thu_Feb_29_15_18_15_2024
# 2914   0.967742  0.952381  0.960000  Thu_Feb_29_00_21_41_2024
# 2915   1.000000  0.919192  0.957895  Thu_Feb_29_00_21_45_2024
#
# [2844 rows x 9 columns]

# %%
data_cleaned[(data_cleaned['precision'] <= 0.3) | (data_cleaned['recall'] <= 0.3)]
# Out:
#      model    prior duplicates_level distortion_level  replicates  precision  \
# 41    Both   Pitman        Very High             High          25   0.002955
# 43    Both   Pitman              Low             High          25   0.000123
# 48    Both   Pitman           Medium             High          25   0.000975
# 51    Both   Pitman             High             High          25   0.002608
# 54    Both   Pitman             High             High          26   0.002608
# ...    ...      ...              ...              ...         ...        ...
# 1925  None  uniform              Low             High          47   0.258883
# 1935  None  uniform              Low             High          48   0.265625
# 1940  None  uniform              Low             High          49   0.274193
# 1943  None  uniform              Low              Low          49   0.298507
# 1953  None  uniform              Low             High          50   0.256281
#
#         recall   f1score                      date
# 41    1.000000  0.005893  Wed_Feb_28_11_14_53_2024
# 43    1.000000  0.000245  Wed_Feb_28_11_14_46_2024
# 48    1.000000  0.001948  Wed_Feb_28_11_14_48_2024
# 51    1.000000  0.005202  Wed_Feb_28_11_14_51_2024
# 54    1.000000  0.005202  Wed_Feb_28_11_15_31_2024
# ...        ...       ...                       ...
# 1925  0.850000  0.396887  Wed_Feb_28_23_05_35_2024
# 1935  0.850000  0.404762  Wed_Feb_28_23_06_36_2024
# 1940  0.850000  0.414634  Wed_Feb_28_23_07_00_2024
# 1943  0.952381  0.454545  Wed_Feb_28_23_06_43_2024
# 1953  0.850000  0.393822  Wed_Feb_28_23_05_59_2024
#
# [57 rows x 9 columns]

# %%
data_cleaned = data_cleaned[(data_cleaned['precision'] >= 0.2) & (data_cleaned['recall'] >= 0.2)]
data_cleaned = data_cleaned.drop_duplicates(subset=['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates'], keep="first")
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned.shape
# Out:
# (2880, 9)

# %%
data_cleaned_20 = pd.read_csv("clean_data20.csv", index_col=0)
data_cleaned = pd.concat([data_cleaned, data_cleaned_20])
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned.to_csv("clean_data50.csv")

# %%
# # Select the columns of interest
# columns_of_interest = ['model', 'prior', 'duplicates_level', 'distortion_level', 'replicates']
# df_selected = data_cleaned[columns_of_interest]


# # Option 2: Count across selected columns (if you want a total count regardless of the column)
# total_count = df_selected[['model', 'prior', 'replicates']].value_counts() # Sorting by index (the number) for better readability
# print("Total count across selected columns:")
# print(total_count)

# %%
data_cleaned = data_cleaned.replace("Bounded NBD", "BNBD4")
data_cleaned
# Out:
#              model   prior duplicates_level distortion_level  replicates  \
# 0             Both  Pitman        Very High             High          21
# 1             Both  Pitman             High             High          21
# 2             Both  Pitman           Medium              Low          21
# 3             Both  Pitman              Low              Low          21
# 4             Both  Pitman        Very High              Low          21
# ...            ...     ...              ...              ...         ...
# 4795  No Empirical   BNBD4           Medium             High          16
# 4796  No Empirical   BNBD4           Medium             High          17
# 4797  No Empirical   BNBD4           Medium             High          18
# 4798  No Empirical   BNBD4           Medium             High          19
# 4799  No Empirical   BNBD4           Medium             High          20
#
#       precision    recall   f1score                      date  num_iter
# 0      1.000000  0.794769  0.885650  Fri_Feb__9_08_51_26_2024       NaN
# 1      1.000000  0.688249  0.815341  Fri_Feb__9_08_51_30_2024       NaN
# 2      0.997807  0.919192  0.956888  Tue_Feb__6_20_11_45_2024       NaN
# 3      0.967742  0.952381  0.960000  Tue_Feb__6_20_11_41_2024       NaN
# 4      1.000000  0.921762  0.959288  Tue_Feb__6_20_11_52_2024       NaN
# ...         ...       ...       ...                       ...       ...
# 4795   0.984456  0.780288  0.870561                       NaN   50000.0
# 4796   0.994609  0.757700  0.860140                       NaN   50000.0
# 4797   0.991758  0.741273  0.848414                       NaN   50000.0
# 4798   0.981959  0.782341  0.870857                       NaN   50000.0
# 4799   0.989189  0.751540  0.854142                       NaN   50000.0
#
# [4800 rows x 10 columns]

# %%
data_BNBD = pd.read_csv("clean_data_BNBD.csv", index_col=0)
data_BNBD['prior'] = 'BNBD' + data_BNBD['cluster_size'].astype(str) 
data_BNBD.drop('cluster_size', axis=1, inplace=True)
data_BNBD
# Out:
#              model  num_iter duplicates_level distortion_level  precision  \
# 0             Both     10000             High              Low   1.000000
# 3             Both     10000             High              Low   1.000000
# 5             Both     10000             High              Low   1.000000
# 7             Both     10000             High              Low   1.000000
# 20            Both     10000             High              Low   1.000000
# ...            ...       ...              ...              ...        ...
# 3822  No Empirical     50000           Medium             High   0.989610
# 3823  No Empirical     50000           Medium             High   0.987047
# 3824  No Empirical     50000           Medium             High   0.989218
# 3825  No Empirical     50000           Medium             High   0.984252
# 3826  No Empirical     50000           Medium             High   0.988981
#
#         recall   f1score                      date   prior
# 0     0.336262  0.503287  Wed_Mar__6_12_25_12_2024   BNBD2
# 3     0.338658  0.505967  Wed_Mar__6_11_22_00_2024   BNBD2
# 5     0.337859  0.505075  Wed_Mar__6_12_56_55_2024   BNBD2
# 7     0.337061  0.504182  Wed_Mar__6_14_05_23_2024   BNBD2
# 20    0.337061  0.504182  Wed_Mar__6_13_31_31_2024   BNBD2
# ...        ...       ...                       ...     ...
# 3822  0.782341  0.873853  Tue_Mar__5_16_44_22_2024  BNBD10
# 3823  0.782341  0.872852  Tue_Mar__5_19_14_25_2024  BNBD10
# 3824  0.753593  0.855478  Tue_Mar__5_17_33_24_2024  BNBD10
# 3825  0.770020  0.864055  Tue_Mar__5_20_03_56_2024  BNBD10
# 3826  0.737166  0.844706  Tue_Mar__5_18_22_37_2024  BNBD10
#
# [3200 rows x 9 columns]

# %%
data_cleaned = pd.concat([data_cleaned, data_BNBD])
data_cleaned.reset_index(drop=True, inplace=True)
data_cleaned
# Out:
#              model   prior duplicates_level distortion_level  replicates  \
# 0             Both  Pitman        Very High             High        21.0
# 1             Both  Pitman             High             High        21.0
# 2             Both  Pitman           Medium              Low        21.0
# 3             Both  Pitman              Low              Low        21.0
# 4             Both  Pitman        Very High              Low        21.0
# ...            ...     ...              ...              ...         ...
# 7995  No Empirical  BNBD10           Medium             High         NaN
# 7996  No Empirical  BNBD10           Medium             High         NaN
# 7997  No Empirical  BNBD10           Medium             High         NaN
# 7998  No Empirical  BNBD10           Medium             High         NaN
# 7999  No Empirical  BNBD10           Medium             High         NaN
#
#       precision    recall   f1score                      date  num_iter
# 0      1.000000  0.794769  0.885650  Fri_Feb__9_08_51_26_2024       NaN
# 1      1.000000  0.688249  0.815341  Fri_Feb__9_08_51_30_2024       NaN
# 2      0.997807  0.919192  0.956888  Tue_Feb__6_20_11_45_2024       NaN
# 3      0.967742  0.952381  0.960000  Tue_Feb__6_20_11_41_2024       NaN
# 4      1.000000  0.921762  0.959288  Tue_Feb__6_20_11_52_2024       NaN
# ...         ...       ...       ...                       ...       ...
# 7995   0.989610  0.782341  0.873853  Tue_Mar__5_16_44_22_2024   50000.0
# 7996   0.987047  0.782341  0.872852  Tue_Mar__5_19_14_25_2024   50000.0
# 7997   0.989218  0.753593  0.855478  Tue_Mar__5_17_33_24_2024   50000.0
# 7998   0.984252  0.770020  0.864055  Tue_Mar__5_20_03_56_2024   50000.0
# 7999   0.988981  0.737166  0.844706  Tue_Mar__5_18_22_37_2024   50000.0
#
# [8000 rows x 10 columns]

# %%
pd.set_option('display.max_rows', 10)

# %%
# Group by the specified columns and compute mean and standard deviation for precision, recall, and f1score
grouped_data = data_cleaned.groupby(['model', 'prior', 'duplicates_level', 'distortion_level'])

# Compute mean
median_values = grouped_data[['precision', 'recall', 'f1score']].median().reset_index()

# Compute standard deviation
std_dev_values = grouped_data[['precision', 'recall', 'f1score']].std().reset_index()

# Rename columns for clarity
median_values.rename(columns={
    'precision': 'precision_median', 
    'recall': 'recall_median', 
    'f1score': 'f1score_median'}, inplace=True)

std_dev_values.rename(columns={
    'precision': 'precision_std', 
    'recall': 'recall_std', 
    'f1score': 'f1score_std'}, inplace=True)

# Display the mean values
median_values.head(), std_dev_values.head()

# Define the metrics you want to calculate the bounds for
metrics = ['precision', 'recall', 'f1score']

# Initialize an empty DataFrame to store the bounds
bounds_df = pd.DataFrame()

# Calculate the lower and upper bounds for each metric
for metric in metrics:
    # Calculate the quantiles for the current metric
    bounds = grouped_data[metric].quantile([0.025, 0.975]).unstack(level=-1)
    
    # Rename columns to reflect the metric and bound type
    bounds.columns = [f'{metric}_lower_bound', f'{metric}_upper_bound']
    
    # If bounds_df is empty, initialize it with the current bounds
    if bounds_df.empty:
        bounds_df = bounds.reset_index()
    else:
        # Otherwise, merge the new bounds into the existing DataFrame
        bounds_df = bounds_df.merge(bounds.reset_index(), on=['model', 'prior', 'duplicates_level', 'distortion_level'])

# Now you have a DataFrame with lower and upper bounds for each metric
bounds_df
# Out:
#     model    prior duplicates_level distortion_level  precision_lower_bound  \
# 0    Both   BNBD10             High             High               0.996025
# 1    Both   BNBD10             High              Low               1.000000
# 2    Both   BNBD10              Low             High               1.000000
# 3    Both   BNBD10              Low              Low               0.967742
# 4    Both   BNBD10           Medium             High               0.988872
# ..    ...      ...              ...              ...                    ...
# 155  None  uniform              Low              Low               0.292292
# 156  None  uniform           Medium             High               0.974249
# 157  None  uniform           Medium              Low               0.997203
# 158  None  uniform        Very High             High               0.999331
# 159  None  uniform        Very High              Low               1.000000
#
#      precision_upper_bound  recall_lower_bound  recall_upper_bound  \
# 0                 1.000000            0.690028            0.760012
# 1                 1.000000            0.934066            0.940535
# 2                 1.000000            0.733333            0.750000
# 3                 1.000000            0.952381            0.952381
# 4                 0.991758            0.733522            0.742864
# ..                     ...                 ...                 ...
# 155               0.323060            0.952381            0.952381
# 156               0.988896            0.847485            0.864476
# 157               1.000000            0.918636            0.925253
# 158               1.000000            0.819215            0.834591
# 159               1.000000            0.921220            0.923258
#
#      f1score_lower_bound  f1score_upper_bound
# 0               0.816115             0.862860
# 1               0.965717             0.969356
# 2               0.846154             0.857143
# 3               0.960000             0.975610
# 4               0.842288             0.848689
# ..                   ...                  ...
# 155             0.447303             0.482462
# 156             0.908617             0.922111
# 157             0.955857             0.961175
# 158             0.900625             0.909838
# 159             0.958994             0.960098
#
# [160 rows x 10 columns]

# %%
# Merge mean and standard deviation dataframes on the groupby columns
combined_data = pd.merge(median_values, bounds_df,
                         on=['model', 'prior', 'duplicates_level', 'distortion_level'])

combined_data = combined_data.replace({"None": "Neither"})
pd.set_option('display.max_rows', None)


# Display the combined dataframe
combined_data
# Out:
#             model    prior duplicates_level distortion_level  \
# 0            Both   BNBD10             High             High
# 1            Both   BNBD10             High              Low
# 2            Both   BNBD10              Low             High
# 3            Both   BNBD10              Low              Low
# 4            Both   BNBD10           Medium             High
# 5            Both   BNBD10           Medium              Low
# 6            Both   BNBD10        Very High             High
# 7            Both   BNBD10        Very High              Low
# 8            Both    BNBD2             High             High
# 9            Both    BNBD2             High              Low
# 10           Both    BNBD2              Low             High
# 11           Both    BNBD2              Low              Low
# 12           Both    BNBD2           Medium             High
# 13           Both    BNBD2           Medium              Low
# 14           Both    BNBD2        Very High             High
# 15           Both    BNBD2        Very High              Low
# 16           Both    BNBD4             High             High
# 17           Both    BNBD4             High              Low
# 18           Both    BNBD4              Low             High
# 19           Both    BNBD4              Low              Low
# 20           Both    BNBD4           Medium             High
# 21           Both    BNBD4           Medium              Low
# 22           Both    BNBD4        Very High             High
# 23           Both    BNBD4        Very High              Low
# 24           Both   Pitman             High             High
# 25           Both   Pitman             High              Low
# 26           Both   Pitman              Low             High
# 27           Both   Pitman              Low              Low
# 28           Both   Pitman           Medium             High
# 29           Both   Pitman           Medium              Low
# 30           Both   Pitman        Very High             High
# 31           Both   Pitman        Very High              Low
# 32           Both  uniform             High             High
# 33           Both  uniform             High              Low
# 34           Both  uniform              Low             High
# 35           Both  uniform              Low              Low
# 36           Both  uniform           Medium             High
# 37           Both  uniform           Medium              Low
# 38           Both  uniform        Very High             High
# 39           Both  uniform        Very High              Low
# 40        Neither   BNBD10             High             High
# 41        Neither   BNBD10             High              Low
# 42        Neither   BNBD10              Low             High
# 43        Neither   BNBD10              Low              Low
# 44        Neither   BNBD10           Medium             High
# 45        Neither   BNBD10           Medium              Low
# 46        Neither   BNBD10        Very High             High
# 47        Neither   BNBD10        Very High              Low
# 48        Neither    BNBD2             High             High
# 49        Neither    BNBD2             High              Low
# 50        Neither    BNBD2              Low             High
# 51        Neither    BNBD2              Low              Low
# 52        Neither    BNBD2           Medium             High
# 53        Neither    BNBD2           Medium              Low
# 54        Neither    BNBD2        Very High             High
# 55        Neither    BNBD2        Very High              Low
# 56        No Diri   BNBD10             High             High
# 57        No Diri   BNBD10             High              Low
# 58        No Diri   BNBD10              Low             High
# 59        No Diri   BNBD10              Low              Low
# 60        No Diri   BNBD10           Medium             High
# 61        No Diri   BNBD10           Medium              Low
# 62        No Diri   BNBD10        Very High             High
# 63        No Diri   BNBD10        Very High              Low
# 64        No Diri    BNBD2             High             High
# 65        No Diri    BNBD2             High              Low
# 66        No Diri    BNBD2              Low             High
# 67        No Diri    BNBD2              Low              Low
# 68        No Diri    BNBD2           Medium             High
# 69        No Diri    BNBD2           Medium              Low
# 70        No Diri    BNBD2        Very High             High
# 71        No Diri    BNBD2        Very High              Low
# 72        No Diri    BNBD4             High             High
# 73        No Diri    BNBD4             High              Low
# 74        No Diri    BNBD4              Low             High
# 75        No Diri    BNBD4              Low              Low
# 76        No Diri    BNBD4           Medium             High
# 77        No Diri    BNBD4           Medium              Low
# 78        No Diri    BNBD4        Very High             High
# 79        No Diri    BNBD4        Very High              Low
# 80        No Diri   Pitman             High             High
# 81        No Diri   Pitman             High              Low
# 82        No Diri   Pitman              Low             High
# 83        No Diri   Pitman              Low              Low
# 84        No Diri   Pitman           Medium             High
# 85        No Diri   Pitman           Medium              Low
# 86        No Diri   Pitman        Very High             High
# 87        No Diri   Pitman        Very High              Low
# 88        No Diri  uniform             High             High
# 89        No Diri  uniform             High              Low
# 90        No Diri  uniform              Low             High
# 91        No Diri  uniform              Low              Low
# 92        No Diri  uniform           Medium             High
# 93        No Diri  uniform           Medium              Low
# 94        No Diri  uniform        Very High             High
# 95        No Diri  uniform        Very High              Low
# 96   No Empirical   BNBD10             High             High
# 97   No Empirical   BNBD10             High              Low
# 98   No Empirical   BNBD10              Low             High
# 99   No Empirical   BNBD10              Low              Low
# 100  No Empirical   BNBD10           Medium             High
# 101  No Empirical   BNBD10           Medium              Low
# 102  No Empirical   BNBD10        Very High             High
# 103  No Empirical   BNBD10        Very High              Low
# 104  No Empirical    BNBD2             High             High
# 105  No Empirical    BNBD2             High              Low
# 106  No Empirical    BNBD2              Low             High
# 107  No Empirical    BNBD2              Low              Low
# 108  No Empirical    BNBD2           Medium             High
# 109  No Empirical    BNBD2           Medium              Low
# 110  No Empirical    BNBD2        Very High             High
# 111  No Empirical    BNBD2        Very High              Low
# 112  No Empirical    BNBD4             High             High
# 113  No Empirical    BNBD4             High              Low
# 114  No Empirical    BNBD4              Low             High
# 115  No Empirical    BNBD4              Low              Low
# 116  No Empirical    BNBD4           Medium             High
# 117  No Empirical    BNBD4           Medium              Low
# 118  No Empirical    BNBD4        Very High             High
# 119  No Empirical    BNBD4        Very High              Low
# 120  No Empirical   Pitman             High             High
# 121  No Empirical   Pitman             High              Low
# 122  No Empirical   Pitman              Low             High
# 123  No Empirical   Pitman              Low              Low
# 124  No Empirical   Pitman           Medium             High
# 125  No Empirical   Pitman           Medium              Low
# 126  No Empirical   Pitman        Very High             High
# 127  No Empirical   Pitman        Very High              Low
# 128  No Empirical  uniform             High             High
# 129  No Empirical  uniform             High              Low
# 130  No Empirical  uniform              Low             High
# 131  No Empirical  uniform              Low              Low
# 132  No Empirical  uniform           Medium             High
# 133  No Empirical  uniform           Medium              Low
# 134  No Empirical  uniform        Very High             High
# 135  No Empirical  uniform        Very High              Low
# 136       Neither    BNBD4             High             High
# 137       Neither    BNBD4             High              Low
# 138       Neither    BNBD4              Low             High
# 139       Neither    BNBD4              Low              Low
# 140       Neither    BNBD4           Medium             High
# 141       Neither    BNBD4           Medium              Low
# 142       Neither    BNBD4        Very High             High
# 143       Neither    BNBD4        Very High              Low
# 144       Neither   Pitman             High             High
# 145       Neither   Pitman             High              Low
# 146       Neither   Pitman              Low             High
# 147       Neither   Pitman              Low              Low
# 148       Neither   Pitman           Medium             High
# 149       Neither   Pitman           Medium              Low
# 150       Neither   Pitman        Very High             High
# 151       Neither   Pitman        Very High              Low
# 152       Neither  uniform             High             High
# 153       Neither  uniform             High              Low
# 154       Neither  uniform              Low             High
# 155       Neither  uniform              Low              Low
# 156       Neither  uniform           Medium             High
# 157       Neither  uniform           Medium              Low
# 158       Neither  uniform        Very High             High
# 159       Neither  uniform        Very High              Low
#
#      precision_median  recall_median  f1score_median  precision_lower_bound  \
# 0            1.000000       0.694644        0.819811               0.996025
# 1            1.000000       0.936901        0.967423               1.000000
# 2            1.000000       0.750000        0.857143               1.000000
# 3            0.983607       0.952381        0.967742               0.967742
# 4            0.989011       0.739220        0.846063               0.988872
# 5            1.000000       0.923232        0.960084               0.995628
# 6            0.997480       0.779343        0.875918               0.997407
# 7            1.000000       0.921762        0.959288               1.000000
# 8            0.991968       0.294165        0.454041               0.989173
# 9            1.000000       0.337061        0.504182               1.000000
# 10           1.000000       0.750000        0.857143               1.000000
# 11           0.982456       0.888889        0.933333               0.965048
